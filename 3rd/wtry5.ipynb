# %%
import os
from torchvision.transforms.functional import to_tensor
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import GATConv
import numpy as np
from torchvision import models, transforms, datasets
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
import os
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import networkx as nx
from PIL import Image
# Out:
# c:\Users\aydhi\OneDrive\Documents\capstone\TRY2\.venv\Lib\site-packages\torch_geometric\typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: [WinError 127] The specified procedure could not be found
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# c:\Users\aydhi\OneDrive\Documents\capstone\TRY2\.venv\Lib\site-packages\torch_geometric\typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: [WinError 127] The specified procedure could not be found
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# c:\Users\aydhi\OneDrive\Documents\capstone\TRY2\.venv\Lib\site-packages\torch_geometric\typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: [WinError 127] The specified procedure could not be found
#   warnings.warn(
# c:\Users\aydhi\OneDrive\Documents\capstone\TRY2\.venv\Lib\site-packages\torch_geometric\typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: [WinError 127] The specified procedure could not be found
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
import os
import time
from PIL import Image
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

def extract_patches_from_wsi_folder(folder_path, patch_size=224, stride=224, visualize=False, save_path="patches", break_interval=10, break_time=5):
    
    if not os.path.exists(save_path):
        os.makedirs(save_path)
    
    processed_images = 0
    
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith(".png"):
                image_path = os.path.join(root, file)
                try:
                    image = Image.open(image_path).convert("RGB")
                    width, height = image.size
                    
                    for y in range(0, height - patch_size + 1, stride):
                        for x in range(0, width - patch_size + 1, stride):
                            patch = image.crop((x, y, x + patch_size, y + patch_size))
                            patch_filename = f"{os.path.splitext(file)[0]}_{x}_{y}.png"
                            patch.save(os.path.join(save_path, patch_filename))
                    
                    processed_images += 1
                    if processed_images % break_interval == 0:
                        print(f"Processed {processed_images} images. Taking a {break_time}-second break to prevent SSD overload...")
                        time.sleep(break_time)
                
                except Image.DecompressionBombError:
                    print(f"Skipping large image (possible decompression bomb): {image_path}")


# extract_patches_from_wsi_folder("data/", visualize=True)

# %%
class FeatureExtractor(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = models.resnet152(pretrained=True)
        self.model.fc = nn.Linear(2048, 512)  # Reduce output size to 512

    def forward(self, x):
        return self.model(x)

feature_extractor = FeatureExtractor().to(device).eval()

# %%
def load_trained_gat_model(model_path, input_dim=512, hidden_dim=64, output_dim=3):
    from torch_geometric.nn import GATConv
    class GATClassifier(nn.Module):
        def __init__(self, input_dim, hidden_dim, output_dim, heads=4):
            super().__init__()
            self.gat1 = GATConv(input_dim, hidden_dim, heads=heads, concat=True)
            self.gat2 = GATConv(hidden_dim * heads, hidden_dim, heads=heads, concat=True)
            self.gat3 = GATConv(hidden_dim * heads, output_dim, heads=1, concat=False)
        
        def forward(self, data):
            x, edge_index = data.x.to(device), data.edge_index.to(device)
            x = torch.relu(self.gat1(x, edge_index))
            x = torch.relu(self.gat2(x, edge_index))
            x = self.gat3(x, edge_index)
            return x
    
    model = GATClassifier(input_dim, hidden_dim, output_dim).to(device)
    model.load_state_dict(torch.load(model_path))
    model.eval()
    return model

# Load trained model
model = load_trained_gat_model("best_model.pth")
# Out:
# C:\Users\aydhi\AppData\Local\Temp\ipykernel_28428\1759631107.py:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
def classify_patch(image):
    image = transform(image).unsqueeze(0).to(device)
    with torch.no_grad():
        feature = feature_extractor(image).cpu()
    logits = model(Data(x=feature.to(device), edge_index=torch.tensor([[0], [0]], dtype=torch.long).to(device)))
    pred_label = logits.argmax().item()
    return pred_label

# %%
def classify_existing_patches(patch_folder, visualize=False):
    for root, _, files in os.walk(patch_folder):
        for file in files:
            if file.lower().endswith(".png"):
                patch_path = os.path.join(root, file)
                patch = Image.open(patch_path).convert("RGB")
                pred_label = classify_patch(patch)
                
                if pred_label == 1:  # Assuming 1 indicates cancer
                    print(f"Cancer detected in patch: {patch_path} (Label: {pred_label})")
                    if visualize:
                        plt.imshow(patch)
                        plt.title(f"Cancer Patch: {file} (Label: {pred_label})")
                        plt.axis("off")
                        plt.show()

# %%
classify_existing_patches("patches/")
# Out:
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10080_10752.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10080_12096.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10080_12768.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10080_13216.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10080_13664.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10080_2912.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10080_3584.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10080_5152.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10080_7168.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10080_7392.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10304_11648.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10304_12320.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10304_13216.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10304_13664.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10304_7168.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10304_7392.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10304_8960.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10528_12544.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10528_3136.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10528_3584.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10528_7168.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10528_7392.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10528_7840.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10528_9184.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10752_10080.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10752_11648.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10752_12096.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10752_13216.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10752_13664.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10752_3360.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10752_3584.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10752_8288.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10752_8960.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10976_10528.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10976_12768.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10976_13216.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10976_13664.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10976_2912.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10976_3136.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10976_3360.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10976_6944.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10976_7840.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10976_8064.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10976_8288.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_10976_8512.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11200_10976.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11200_12096.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11200_12544.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11200_12768.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11200_13216.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11200_13664.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11200_3136.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11200_3360.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11200_3808.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11200_7168.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11200_7840.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11200_8064.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11200_8288.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11200_8512.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11200_8736.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11424_10528.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11424_11200.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11424_11424.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11424_11872.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11424_12320.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11424_13664.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11424_13888.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11424_3136.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11424_7840.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11424_8064.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11424_8288.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11424_8736.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11424_8960.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11648_10528.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11648_10976.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11648_11200.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11648_11424.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11648_12544.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11648_13216.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11648_1344.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11648_13888.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11648_7616.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11648_8064.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11648_8512.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11648_8736.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11648_8960.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11872_10304.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11872_10976.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11872_11200.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11872_11872.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11872_12320.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11872_672.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11872_7840.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11872_8736.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11872_8960.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11872_9184.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_11872_9856.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12096_10528.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12096_1120.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12096_11872.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12096_3136.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12096_672.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12096_7840.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12096_8064.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12096_8288.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12096_8736.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12096_8960.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12096_9408.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12096_9632.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12096_9856.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12320_10528.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12320_10752.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12320_10976.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12320_11200.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12320_13216.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12320_13664.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12320_3136.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12320_8064.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12320_8736.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12320_8960.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12320_9632.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_10304.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_10528.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_10752.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_10976.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_11200.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_11872.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_1344.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_13664.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_2912.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_3136.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_7168.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_8064.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_8288.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_8512.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_8960.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12544_9408.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12768_10304.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12768_10528.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12768_10752.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12768_10976.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12768_11648.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12768_11872.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12768_13216.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12768_13888.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12768_3136.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12768_6720.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12768_7840.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12768_896.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12768_8960.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12768_9856.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12992_10752.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12992_10976.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12992_11424.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12992_11648.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12992_12320.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12992_13888.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12992_3136.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12992_7392.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12992_8064.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12992_8288.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12992_8512.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_12992_896.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_10752.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_10976.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_1120.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_12320.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_13216.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_13888.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_2240.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_2912.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_3136.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_6272.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_6496.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_6720.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_8064.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_8512.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_8736.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_9184.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13216_9632.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_10080.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_10976.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_1120.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_11424.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_11872.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_12096.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_12768.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_1344.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_13888.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_2464.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_2688.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_6496.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_6944.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_7840.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_8512.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_8736.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_8960.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_9408.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_9632.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13440_9856.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13664_10080.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13664_10528.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13664_10752.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13664_1120.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13664_11424.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13664_13216.png (Label: 1)
# Cancer detected in patch: patches/TCGA-44-3917-11A-01-BS1.f7097e3f-4b6d-48e5-b06e-c0cd4e9fcc56_13664_13888.png (Label: 1)
